# %%
def matrix(n):
    gen = ( (i * j for j in range(1, n+1))
        for i in range(1, n+1)
    )
    return gen

# %%
m = list(matrix(5))

# %%
m
# Out:
# [<generator object matrix.<locals>.<genexpr>.<genexpr> at 0x10842cd40>,
#  <generator object matrix.<locals>.<genexpr>.<genexpr> at 0x10842cc70>,
#  <generator object matrix.<locals>.<genexpr>.<genexpr> at 0x10842c930>,
#  <generator object matrix.<locals>.<genexpr>.<genexpr> at 0x10842cba0>,
#  <generator object matrix.<locals>.<genexpr>.<genexpr> at 0x10842cad0>]

# %%
def matrix_iterator(n):
    for row in matrix(n):
        for item in row:
            yield item

# %%
for item in matrix_iterator(3):
    print(item)
# Out:
# 1
# 2
# 3
# 2
# 4
# 6
# 3
# 6
# 9

# %%
def matrix_iterator(n):
    for row in matrix(n):
        yield from row

# %%
for item in matrix_iterator(3):
    print(item)
# Out:
# 1
# 2
# 3
# 2
# 4
# 6
# 3
# 6
# 9

# %%
file_1 = 'car-brands-1.txt'
file_2 = 'car-brands-2.txt'
file_3 = 'car-brands-3.txt'
files = file_1, file_2, file_3

# %%
files
# Out:
# ('car-brands-1.txt', 'car-brands-2.txt', 'car-brands-3.txt')

# %%
brands = []
with open(file_1) as f:
    for brand in f:
        brands.append(brand.strip('\n'))

with open(file_2) as f:
    for brand in f:
        brands.append(brand.strip('\n'))

with open(file_3) as f:
    for brand in f:
        brands.append(brand.strip('\n'))

# %%
brands
# Out:
# ['Chrysler',
#  'Skoda',
#  'Cadillac',
#  'Corvette',
#  'Noble',
#  'Tata',
#  'Honda',
#  'BMW',
#  'Ford',
#  'Dodge',
#  'Humer',
#  'Holden',
#  'Bristol',
#  'Porsche',
#  'Maybach',
#  'Lotus',
#  'Toyota',
#  'MB Roadcars',
#  'Superformance',
#  'Ascari',
#  'Mini',
#  'Kia',
#  'Aston Martin',
#  'Peugeot',
#  'Saab',
#  'Renault',
#  'LandRover',
#  'Saturn',
#  'Smart',
#  'Perodua',
#  'Radical',
#  'Ariel',
#  'Brooke',
#  'Ssangyong',
#  'Marcos',
#  'Invicta',
#  'Subaru',
#  'Alpina',
#  'Proton',
#  'Isuzu',
#  'Koenigsegg',
#  'Fiat',
#  'Lexus',
#  'Tesla',
#  'SSC',
#  'Hyundai',
#  'Mazda',
#  'Spyker',
#  'Jeep',
#  'Rolls-Royce',
#  'TVR',
#  'Morgan',
#  'Citroen',
#  'Mercedes-Benz',
#  'Westfield',
#  'Nissan',
#  'Caerham',
#  'Daihatsu',
#  'Lamborghini',
#  'Shelby',
#  'Vauxhal',
#  'Bentley',
#  'Chrysler',
#  'Skoda',
#  'Cadillac',
#  'Corvette',
#  'Noble',
#  'Tata',
#  'Honda',
#  'BMW',
#  'Ford',
#  'Dodge',
#  'Humer',
#  'Holden',
#  'Bristol',
#  'Porsche',
#  'Maybach',
#  'Lobini',
#  'Maserati',
#  'Callaway',
#  'Seat',
#  'Gumpert',
#  'Chevrolet',
#  'Chrysler',
#  'Skoda',
#  'Holden',
#  'Bristol',
#  'Porsche',
#  'Maybach',
#  'Lotus',
#  'Toyota',
#  'Peugeot',
#  'Saab',
#  'Renault',
#  'LandRover',
#  'Saturn',
#  'Smart',
#  'Perodua',
#  'Radical',
#  'Ariel',
#  'Brooke',
#  'Koenigsegg',
#  'Fiat',
#  'Lexus',
#  'Tesla',
#  'SSC',
#  'Hyundai',
#  'Mazda',
#  'Spyker',
#  'TVR',
#  'Morgan',
#  'Citroen',
#  'Mercedes-Benz',
#  'Westfield',
#  'Nissan',
#  'Caerham',
#  'Daihatsu',
#  'Lamborghini',
#  'Shelby',
#  'Vauxhal',
#  'Bentley']

# %%
def brands(*files):
    for f_name in files:
        with open(f_name) as f:
            for line in f:
                yield line.strip('\n')

# %%
for brand in brands(*files):
    print(brand)
# Out:
# Chrysler
# Skoda
# Cadillac
# Corvette
# Noble
# Tata
# Honda
# BMW
# Ford
# Dodge
# Humer
# Holden
# Bristol
# Porsche
# Maybach
# Lotus
# Toyota
# MB Roadcars
# Superformance
# Ascari
# Mini
# Kia
# Aston Martin
# Peugeot
# Saab
# Renault
# LandRover
# Saturn
# Smart
# Perodua
# Radical
# Ariel
# Brooke
# Ssangyong
# Marcos
# Invicta
# Subaru
# Alpina
# Proton
# Isuzu
# Koenigsegg
# Fiat
# Lexus
# Tesla
# SSC
# Hyundai
# Mazda
# Spyker
# Jeep
# Rolls-Royce
# TVR
# Morgan
# Citroen
# Mercedes-Benz
# Westfield
# Nissan
# Caerham
# Daihatsu
# Lamborghini
# Shelby
# Vauxhal
# Bentley
# Chrysler
# Skoda
# Cadillac
# Corvette
# Noble
# Tata
# Honda
# BMW
# Ford
# Dodge
# Humer
# Holden
# Bristol
# Porsche
# Maybach
# Lobini
# Maserati
# Callaway
# Seat
# Gumpert
# Chevrolet
# Chrysler
# Skoda
# Holden
# Bristol
# Porsche
# Maybach
# Lotus
# Toyota
# Peugeot
# Saab
# Renault
# LandRover
# Saturn
# Smart
# Perodua
# Radical
# Ariel
# Brooke
# Koenigsegg
# Fiat
# Lexus
# Tesla
# SSC
# Hyundai
# Mazda
# Spyker
# TVR
# Morgan
# Citroen
# Mercedes-Benz
# Westfield
# Nissan
# Caerham
# Daihatsu
# Lamborghini
# Shelby
# Vauxhal
# Bentley

# %%
def gen_clean_data(file):
    with open(file) as f:
        for row in f:
            yield row.strip('\n')

# %%
def brands(*files):
    for f_name in files:
        yield from gen_clean_data(f_name)

# %%
list(brands(*files))
# Out:
# ['Chrysler',
#  'Skoda',
#  'Cadillac',
#  'Corvette',
#  'Noble',
#  'Tata',
#  'Honda',
#  'BMW',
#  'Ford',
#  'Dodge',
#  'Humer',
#  'Holden',
#  'Bristol',
#  'Porsche',
#  'Maybach',
#  'Lotus',
#  'Toyota',
#  'MB Roadcars',
#  'Superformance',
#  'Ascari',
#  'Mini',
#  'Kia',
#  'Aston Martin',
#  'Peugeot',
#  'Saab',
#  'Renault',
#  'LandRover',
#  'Saturn',
#  'Smart',
#  'Perodua',
#  'Radical',
#  'Ariel',
#  'Brooke',
#  'Ssangyong',
#  'Marcos',
#  'Invicta',
#  'Subaru',
#  'Alpina',
#  'Proton',
#  'Isuzu',
#  'Koenigsegg',
#  'Fiat',
#  'Lexus',
#  'Tesla',
#  'SSC',
#  'Hyundai',
#  'Mazda',
#  'Spyker',
#  'Jeep',
#  'Rolls-Royce',
#  'TVR',
#  'Morgan',
#  'Citroen',
#  'Mercedes-Benz',
#  'Westfield',
#  'Nissan',
#  'Caerham',
#  'Daihatsu',
#  'Lamborghini',
#  'Shelby',
#  'Vauxhal',
#  'Bentley',
#  'Chrysler',
#  'Skoda',
#  'Cadillac',
#  'Corvette',
#  'Noble',
#  'Tata',
#  'Honda',
#  'BMW',
#  'Ford',
#  'Dodge',
#  'Humer',
#  'Holden',
#  'Bristol',
#  'Porsche',
#  'Maybach',
#  'Lobini',
#  'Maserati',
#  'Callaway',
#  'Seat',
#  'Gumpert',
#  'Chevrolet',
#  'Chrysler',
#  'Skoda',
#  'Holden',
#  'Bristol',
#  'Porsche',
#  'Maybach',
#  'Lotus',
#  'Toyota',
#  'Peugeot',
#  'Saab',
#  'Renault',
#  'LandRover',
#  'Saturn',
#  'Smart',
#  'Perodua',
#  'Radical',
#  'Ariel',
#  'Brooke',
#  'Koenigsegg',
#  'Fiat',
#  'Lexus',
#  'Tesla',
#  'SSC',
#  'Hyundai',
#  'Mazda',
#  'Spyker',
#  'TVR',
#  'Morgan',
#  'Citroen',
#  'Mercedes-Benz',
#  'Westfield',
#  'Nissan',
#  'Caerham',
#  'Daihatsu',
#  'Lamborghini',
#  'Shelby',
#  'Vauxhal',
#  'Bentley']
